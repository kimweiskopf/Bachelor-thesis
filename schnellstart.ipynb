# %%
#File to replace and start the files to calculate the theoretical migration rate
import numpy as np

filename='GT_ward_D10'

# %%
search_mass1=['MU1=3e-3','MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=2e-3','MU1=2e-3','MU1=2e-3',
             'MU1=4e-3','MU1=4e-3','MU1=4e-3',
             'MU1=5e-3','MU1=5e-3','MU1=5e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3']
replace_mass1=['MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=2e-3','MU1=2e-3','MU1=2e-3',
             'MU1=4e-3','MU1=4e-3','MU1=4e-3',
             'MU1=5e-3','MU1=5e-3','MU1=5e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3',
             'MU1=3e-3','MU1=3e-3','MU1=3e-3']


search_sigma0=['SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-4','SIGMA_0=1e-4','SIGMA_0=1e-4',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3']
replace_sigma0=['SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-4','SIGMA_0=1e-4','SIGMA_0=1e-4',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3',
              'SIGMA_0=1e-3','SIGMA_0=1e-3','SIGMA_0=1e-3']

search_alpha=['ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-4','ALPHAVISCOSITY=1e-4','ALPHAVISCOSITY=1e-4',
             'ALPHAVISCOSITY=1e-5','ALPHAVISCOSITY=1e-5']
replace_alpha=['ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3','ALPHAVISCOSITY=1e-3',
             'ALPHAVISCOSITY=1e-4','ALPHAVISCOSITY=1e-4','ALPHAVISCOSITY=1e-4',
             'ALPHAVISCOSITY=1e-5','ALPHAVISCOSITY=1e-5','ALPHAVISCOSITY=1e-5']


search_h0=['H_0=0.06','H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.07','H_0=0.07','H_0=0.07',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06']
replace_h0=['H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.07','H_0=0.07','H_0=0.07',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06',
          'H_0=0.06','H_0=0.06','H_0=0.06']

search_sigmaratio=['SIGMARATIO=0.1','SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2']
replace_sigmaratio=['SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3',
                   'SIGMARATIO=0.1','SIGMARATIO=0.2','SIGMARATIO=0.3']

search_FLARINGINDEX=['FLARINGINDEX=0.3333','FLARINGINDEX=0.3333','FLARINGINDEX=0.3333','FLARINGINDEX=0.3333',
                    'FLARINGINDEX=0.2','FLARINGINDEX=0.2','FLARINGINDEX=0.2',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25']
replace_FLARINGINDEX=['FLARINGINDEX=0.3333','FLARINGINDEX=0.3333','FLARINGINDEX=0.3333',
                    'FLARINGINDEX=0.2','FLARINGINDEX=0.2','FLARINGINDEX=0.2',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25',
                    'FLARINGINDEX=0.25','FLARINGINDEX=0.25','FLARINGINDEX=0.25']

search_index=['index[0]','index[0]','index[0]','index[0]',
              'index[1]','index[1]','index[1]',
              'index[2]','index[2]','index[2]',
              'index[3]','index[3]','index[3]',
              'index[4]','index[4]','index[4]',
              'index[5]','index[5]','index[5]',
              'index[6]','index[6]','index[6]',
              'index[7]','index[7]','index[7]',
              'index[8]','index[8]','index[8]',
              'index[9]','index[9]']
replace_index=['index[0]','index[0]','index[0]',
              'index[1]','index[1]','index[1]',
              'index[2]','index[2]','index[2]',
              'index[3]','index[3]','index[3]',
              'index[4]','index[4]','index[4]',
              'index[5]','index[5]','index[5]',
              'index[6]','index[6]','index[6]',
              'index[7]','index[7]','index[7]',
              'index[8]','index[8]','index[8]',
              'index[9]','index[9]','index[9]']

search_names=["newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3",
"newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4",
"newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_5_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_5_planets_3_1_sigma0_1e_3"]
replace_names=["newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_03",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3_beta_02",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_3",
"newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3","newtheory_h0_007_alpha_1e_3_planets_3_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4","newtheory_h0_006_alpha_1e_3_planets_3_1_sigma0_1e_4",
"newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_2_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_4_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_3_planets_5_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_4_planets_3_1_sigma0_1e_3",
"newtheory_h0_006_alpha_1e_5_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_5_planets_3_1_sigma0_1e_3","newtheory_h0_006_alpha_1e_5_planets_3_1_sigma0_1e_3"]
# Opening our text file in read only mode using the open() function

for i in np.arange(0,len(search_mass1),1):
    with open(f'/home/kim/Dokumente/Uni/Bachelor/Migration/Neuer_Start/Torque_Berechnungen/{filename}.ipynb', 'r') as file:
        # Reading the content of the file
        # using the read() function and storing them in a new variable
        data = file.read()
        
        # Searching and replacing the text using the replace() function
        data = data.replace(search_mass1[i], replace_mass1[i])
        data = data.replace(search_sigma0[i], replace_sigma0[i])
        data = data.replace(search_alpha[i], replace_alpha[i])
        data = data.replace(search_h0[i], replace_h0[i])
        data = data.replace(search_sigmaratio[i], replace_sigmaratio[i])
        data = data.replace(search_FLARINGINDEX[i], replace_FLARINGINDEX[i])
        data = data.replace(search_names[i], replace_names[i])
        data = data.replace(search_index[i], replace_index[i])

    with open(f'/home/kim/Dokumente/Uni/Bachelor/Migration/Neuer_Start/Torque_Berechnungen/{filename}.ipynb', 'w') as file:
        file.write(data)
        print("Text replaced")
        
    # %run GT_ward_D10.ipynb
# Out:
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
# Text replaced
